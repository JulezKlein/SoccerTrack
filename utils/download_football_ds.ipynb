# %%
from roboflow import Roboflow
rf = Roboflow(api_key="xxx")
project = rf.workspace("football-player-identification").project("football-player-detection-jdtdh")
version = project.version(2)
dataset = version.download("yolo26")
